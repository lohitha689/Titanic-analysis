# %% [markdown]
# Total Rows: 891
#
# Missing Values:
#
# Age: 177 missing
#
# Cabin: 687 missing
#
# Embarked: 2 missing
#
# Data Types:
#
# Categorical: Sex, Embarked, Cabin, Name, Ticket
#
# Numerical: Age, Fare, SibSp, Parch

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\GOPI NAIK KORRA\Downloads\train (1).csv')  # Use the correct path if needed
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#df.drop(columns='Cabin', inplace=True)  # Too many missing values

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.shape
# Out:
# (891, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Survived', data=df)
plt.title("Survival Count")
# Out:
# Text(0.5, 1.0, 'Survival Count')

# %%
Survival count is vey less

# %%
sns.histplot(df['Age'].dropna(), bins=30, kde=True)
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
most people are between 25 to 30

# %%
sns.countplot(x='Pclass', data=df)
plt.title("Passenger Class")
# Out:
# Text(0.5, 1.0, 'Passenger Class')

# %%
In Passenger class ,the 3rd class people are more compared with 2nd class and 1st class

# %% [markdown]
# Bivariate Analysis

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival Rate by Gender")
# Out:
# Text(0.5, 1.0, 'Survival Rate by Gender')

# %% [markdown]
# The Survival rate of female is more than male

# %%
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title("Fare vs Survival")
# Out:
# Text(0.5, 1.0, 'Fare vs Survival')

# %%
sns.countplot(x='Embarked', hue='Survived', data=df)
plt.title("Embarkation vs Survival")
# Out:
# Text(0.5, 1.0, 'Embarkation vs Survival')

# %%
C = Cherbourg, Q = Queenstown, S = Southampton
survied people of Southampton are more compared with Queenstown and Cherbourg

# %% [markdown]
# Correlation & Heatmap

# %%
df_corr = df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].copy()
df_corr = df_corr.dropna()  # Drop missing for now
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df_encoded.select_dtypes(include=['number'])

# Plot heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
